# %% [markdown]
# ## Tacotron 2 inference code
# Edit the variables **checkpoint_path** and **text** to match yours and run the entire code to generate plots of mel outputs, alignments and audio synthesis from the generated mel-spectrogram using Griffin-Lim.

# %% [markdown]
# #### Import libraries and setup matplotlib

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pylab as plt

import IPython.display as ipd

import sys
sys.path.append('waveglow2/')
import numpy as np
import torch
import os

from hparams import create_hparams
from model import Tacotron2
from layers import TacotronSTFT, STFT
from audio_processing import griffin_lim
from train import load_model
from text import text_to_sequence
from denoiser import Denoiser

os.environ["CUDA_VISIBLE_DEVICES"]="0"
CUDA_VISIBLE_DEVICES =0
torch.cuda.get_device_name(0)
torch.device('cuda:0')
torch.cuda.set_device(0)

# %%
def plot_data(data, figsize=(16, 4)):
    fig, axes = plt.subplots(1, len(data), figsize=figsize)
    for i in range(len(data)):
        axes[i].imshow(data[i], aspect='auto', origin='bottom', 
                       interpolation='none')

# %% [markdown]
# #### Setup hparams

# %% [markdown]
# Load model from checkpoint

# %%
hparams = create_hparams()
hparams.sampling_rate = 22050
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
#tacotron2_statedict2.pt
checkpoint_path = "outdir/ready/checkpoint_13000"
model = load_model(hparams)
model.load_state_dict(torch.load(checkpoint_path,map_location='cuda:0')['state_dict'])
_ = model.cuda().eval().half()

# %% [markdown]
# #### Load WaveGlow for mel2audio synthesis and denoiser

# %%
waveglow_path = 'waveglow_256channels_universal_v5.pt'
waveglow = torch.load(waveglow_path,map_location='cuda:0')['model']
waveglow.cuda().eval().half()
for k in waveglow.convinv:
    k.float()
denoiser = Denoiser(waveglow)
# Out:
# c:\python37\lib\site-packages\torch\serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.modules.conv.ConvTranspose1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# c:\python37\lib\site-packages\torch\serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# c:\python37\lib\site-packages\torch\serialization.py:649: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
text = "Jebać policję"
sequence = np.array(text_to_sequence(text, ['basic_cleaners']))[None, :]
sequence = torch.autograd.Variable(
    torch.from_numpy(sequence)).cuda().long()

# %%
mel_outputs, mel_outputs_postnet, _, alignments = model.inference(sequence)
plot_data((mel_outputs.float().data.cpu().numpy()[0],
           mel_outputs_postnet.float().data.cpu().numpy()[0],
           alignments.float().data.cpu().numpy()[0].T))
# Out:
# Warning! Reached max decoder steps
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-2e5552ce83d1> in <module>
#       2 plot_data((mel_outputs.float().data.cpu().numpy()[0],
#       3            mel_outputs_postnet.float().data.cpu().numpy()[0],
# ----> 4            alignments.float().data.cpu().numpy()[0].T))
#
# <ipython-input-2-2c6641d807f7> in plot_data(data, figsize)
#       3     for i in range(len(data)):
#       4         axes[i].imshow(data[i], aspect='auto', origin='bottom',
# ----> 5                        interpolation='none')
#
# c:\python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\python37\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5519         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5520                               filternorm=filternorm, filterrad=filterrad,
# -> 5521                               resample=resample, **kwargs)
#    5522
#    5523         im.set_data(X)
#
# c:\python37\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     909             filterrad=filterrad,
#     910             resample=resample,
# --> 911             **kwargs
#     912         )
#     913
#
# c:\python37\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     244         if origin is None:
#     245             origin = mpl.rcParams['image.origin']
# --> 246         cbook._check_in_list(["upper", "lower"], origin=origin)
#     247         self.origin = origin
#     248         self.set_filternorm(filternorm)
#
# c:\python37\lib\site-packages\matplotlib\cbook\__init__.py in _check_in_list(_values, **kwargs)
#    2266             raise ValueError(
#    2267                 "{!r} is not a valid value for {}; supported values are {}"
# -> 2268                 .format(v, k, ', '.join(map(repr, values))))
#    2269
#    2270
#
# ValueError: 'bottom' is not a valid value for origin; supported values are 'upper', 'lower'

# %% [markdown]
# #### Synthesize audio from spectrogram using WaveGlow

# %%
with torch.no_grad():
    audio = waveglow.infer(mel_outputs_postnet, sigma=0.900)
ipd.Audio(audio[0].data.cpu().numpy(), rate=hparams.sampling_rate)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-b606885544d1> in <module>
#       1 with torch.no_grad():
# ----> 2     audio = waveglow.infer(mel_outputs_postnet, sigma=0.900)
#       3 ipd.Audio(audio[0].data.cpu().numpy(), rate=hparams.sampling_rate)
#
# D:\mekatron\waveglow2\glow.py in infer(self, spect, sigma)
#     274             audio_1 = audio[:,n_half:,:]
#     275
# --> 276             output = self.WN[k]((audio_0, spect))
#     277
#     278             s = output[:, n_half:, :]
#
# c:\python37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# D:\mekatron\waveglow2\glow.py in forward(self, forward_input)
#     157         n_channels_tensor = torch.IntTensor([self.n_channels])
#     158
# --> 159         spect = self.cond_layer(spect)
#     160
#     161         for i in range(self.n_layers):
#
# c:\python37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# c:\python37\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     255                             _single(0), self.dilation, self.groups)
#     256         return F.conv1d(input, self.weight, self.bias, self.stride,
# --> 257                         self.padding, self.dilation, self.groups)
#     258
#     259
#
# RuntimeError: CUDA out of memory. Tried to allocate 326.00 MiB (GPU 0; 4.00 GiB total capacity; 636.75 MiB already allocated; 227.83 MiB free; 1.01 GiB reserved in total by PyTorch)

# %% [markdown]
# #### (Optional) Remove WaveGlow bias

# %%
audio_denoised = denoiser(audio, strength=0.06)[:, 0]
ipd.Audio(audio_denoised.cpu().numpy(), rate=hparams.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
